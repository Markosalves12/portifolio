# %%
import pandas as pd

# %%
caminho_excelencia = r"C:\Users\Markos Alves\Downloads\terceirizadas horiginal\Excelencia.xlsx".replace("\\","/")
caminho_ranking  = r"C:\Users\Markos Alves\Downloads\terceirizadas horiginal\Ranking.xlsx".replace("\\","/")
caminho_marlin = r"C:\Users\Markos Alves\Downloads\terceirizadas horiginal\Marlin.xlsx".replace("\\","/")
caminho_DPG = r"C:\Users\Markos Alves\Downloads\terceirizadas horiginal\DPG.xlsx".replace("\\","/")

# %%
#### Adicionando coluna padrão em 'Excelencia'
df_excelencia = pd.read_excel(caminho_excelencia)
df_excelencia = df_excelencia.assign(profit='Excelencia')

#### Adicionando coluna padrão em 'DPG'
df_DPG = pd.read_excel(caminho_DPG)
df_DPG = df_DPG.assign(profit='DPG')

#### Adicionando coluna padrão em 'Ranking'
df_ranking = pd.read_excel(caminho_ranking)
df_ranking = df_ranking.assign(profit='Ranking')

#### Adicionando coluna padrão em 'Ranking'
df_Marlin = pd.read_excel(caminho_marlin)
df_Marlin = df_Marlin.assign(profit='Marlin')

# %%
display(df_DPG.head(3))
display(df_excelencia.head(3))
display(df_Marlin.head(3))
display(df_ranking.head(3))
# Out:
#                                    ST  \
# 0  511878/511570/511857/511868/511862
# 1                512162/512131/512206
# 2                             E-MAIL
#
#                                     C. CUSTO       DATA      HORA  \
# 0  110402/110846/110086/110086/110846/110888 2022-05-16  06:30:00
# 1                       110085/110086/110096 2022-06-09  18:00:00
# 2                                     110065 2022-06-10  18:00:00
#
#                     ORIGEM              DESTINO  VALOR TOTAL  \
# 0                CARAVELAS              FABRICA        330.0
# 1  CONCEIÇÃO DA BARRA COCB  TEIXEIRA DE FREITAS        460.0
# 2  CONCEIÇÃO DA BARRA COCB  TEIXEIRA DE FREITAS        460.0
#
#                   SOLICITANTE                  PASSAGEIRO  PLACA    MOTORISTA  \
# 0   EMMANUEL SILVA DE ANDRADE   EMMANUEL SILVA DE ANDRADE  ETIOS  CRISTOGENES
# 1  FERNANDA FERREIRA CONTARDI  FERNANDA FERREIRA CONTARDI  ETIOS  CRISTOGENES
# ...

# %%
display(df_DPG.shape)
display(df_excelencia.shape)
display(df_Marlin.shape)
display(df_ranking.shape)
# Out:
# (780, 13)
# (14194, 13)
# (239, 13)
# (4714, 13)

# %%
df_para_combinar = [df_DPG, df_excelencia, df_Marlin, df_ranking]

# %%
df_combinado = pd.concat(df_para_combinar)

# %%
df_combinado
# Out:
#                                       ST  \
# 0     511878/511570/511857/511868/511862
# 1                   512162/512131/512206
# 2                                E-MAIL
# 3                   512417/512492/512410
# 4                                 518292
# ...                                  ...
# 4709                              600616
# 4710                              601773
# 4711                              601314
# 4712                              600730
# 4713                              599133
#
#                                        C. CUSTO                 DATA  \
# 0     110402/110846/110086/110086/110846/110888  2022-05-16 00:00:00
# 1                          110085/110086/110096  2022-06-09 00:00:00
# 2                                        110065  2022-06-10 00:00:00
# 3                          110065/110074/160067  2022-06-22 00:00:00
# 4                                        110090  2022-01-04 00:00:00
# ...

# %% [markdown]
# ## Transformações na coluna 'ORIGEM'

# %%
df_combinado.columns
# Out:
# Index(['ST', 'C. CUSTO', 'DATA', 'HORA', 'ORIGEM', 'DESTINO', 'VALOR TOTAL',
#        'SOLICITANTE', 'PASSAGEIRO', 'PLACA', 'MOTORISTA', 'TIPO', 'profit'],
#       dtype='object')

# %%
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.upper()
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.strip()

# %%
df_combinado['ORIGEM'].unique()
# Out:
# array(['CARAVELAS', 'CONCEIÇÃO DA BARRA COCB', 'FABRICA', 'ITABATÃ',
#        'POSTO DA MATA', 'RANCHO ALEGRE', 'SÃO JOSÉ DE ALCOBAÇA',
#        'SITIO RAIZES', 'TEIXEIRA   DE  FREITAS', 'TEIXEIRA', 'ITABATA',
#        'MUCURI', 'VITORIA', 'SÃO MATEUS', 'TEIXEIRA DE FREITAS',
#        'ITABATAN', 'CRUZELÂNDIA', 'CONCEIÇÃO DA BARRA', 'PEDRO CANÁRIO',
#        'GURIRI', 'BRAÇO DO RIO', 'DIVISA BA/ES', 'SAYONARA',
#        'PORTO SEGURO', 'ARACRUZ', 'NANUQUE', 'EUNAPOLIS',
#        'CACHOEIRO DE ITAPEMIRIM', 'ITAUNAS', 'NOVA VENÉCIA', 'FÁBRICA',
#        'NOVA VIÇOSA', 'POUSADA RIO MUCURI', 'VITÓRIA',
#        'CACHOEIRO ITAPEMIRIM', 'TEIXEIRA DE FREIRAS',
#        'CONCEIÇAO DA BARRA', 'FÁBRIA', 'CRISTAL DO NORTE', 'DIVISA-BA-ES',
#        'NOVA VENECIA', 'CURVELO', 'HOSP. PAINEIRAS', 'PEDRO CANARIO',
#        'VERACEL EUNAPOLIS', 'LINHARES', 'FÁBRICA MU', 'MUCURI - BA',
#        'ITABATÃ - BA', 'VITÓRIA - ES', 'SÃO MATEUS - ES',
# ...

# %%
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("   "," ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("  "," ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("    "," ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("ITABATAN","ITABATÃ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("FABRICA","FÁBRICA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("VITORIA","VITÓRIA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("CRUZELANDIA","CRUZELÂNDIA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("VITÓRIIA","VITÓRIA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("ITAUNAS","ITAÚNAS")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("CACH. ITAP.","CACHOEIRO DE ITAPEMIRIM")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C. ITAPEMIRIM","CACHOEIRO DE ITAPEMIRIM")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("TEIXEIRA DE FREITA","TEIXEIRA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("CACHOEIRO ITAPEMIRIM","CACHOEIRO DE ITAPEMIRIM")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("CANARIO","CANÁRIO")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("JOSE","JOSÉ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("DIVISA-BA-ES","DIVISA BA/ES")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("TEIXEIRA DE FREIRAS","TEIXEIRA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("TEIXEIRA","TEIXEIRA DE FREITAS")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("ITABATA","ITABATÃ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C. ITAPEM","CACHOEIRO DE ITAPEMIRIM")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C.ITAPEMIRIM","C.ITAPEM.")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C.ITAPEM.","CACHOEIRO DE ITAPEMIRIM")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("EUNAPOLIS","EUNÁPOLIS")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("V. VELHA","VILA VELHA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("B. GUANDÚ","BAIXO GUANDÚ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("HOTEL","HOTÉL")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("SS","S")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("FÁBRIA","FÁBRICA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("FÁBRICA- MU","FÁBRICA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("FÁBRICA", "FÁBRICA - UNIDADE MUCURI")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace(" - ES","")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace(" - BA","")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace(" - MG","")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("NOVA VENECIA","NOVA VENÉCIA")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("SERRA/ES","SERRA")
# Out:
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\699028480.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("CACH. ITAP.","CACHOEIRO DE ITAPEMIRIM")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\699028480.py:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C. ITAPEMIRIM","CACHOEIRO DE ITAPEMIRIM")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\699028480.py:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("C. ITAPEM","CACHOEIRO DE ITAPEMIRIM")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\699028480.py:21: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
df_combinado['ORIGEM'].unique()
# Out:
# array(['CARAVELAS', 'CONCEIÇÃO DA BARRA COCB', 'FÁBRICA - UNIDADE MUCURI',
#        'ITABATÃ', 'POSTO DA MATA', 'RANCHO ALEGRE',
#        'SÃO JOSÉ DE ALCOBAÇA', 'SITIO RAIZES', 'TEIXEIRA DE FREITAS',
#        'MUCURI', 'VITÓRIA', 'SÃO MATEUS', 'CRUZELÂNDIA',
#        'CONCEIÇÃO DA BARRA', 'PEDRO CANÁRIO', 'GURIRI', 'BRAÇO DO RIO',
#        'DIVISA BA/ES', 'SAYONARA', 'PORTO SEGURO', 'ARACRUZ', 'NANUQUE',
#        'EUNÁPOLIS', 'CACHOEIRO DE ITAPEMIRIM', 'ITAÚNAS', 'NOVA VENÉCIA',
#        'NOVA VIÇOSA', 'POUSADA RIO MUCURI', 'CONCEIÇAO DA BARRA',
#        'CRISTAL DO NORTE', 'CURVELO', 'HOSP. PAINEIRAS',
#        'VERACEL EUNÁPOLIS', 'LINHARES', 'FÁBRICA - UNIDADE MUCURI MU',
#        'TRAJETO EXTRA', 'VITÓRIA/AEROPORTO', 'SERRA', 'ITAMARAJU',
#        'TEIXEIRA DE FREITAS - AEROPORTO', 'VILA VELHA',
#        'FÁBRICA - UNIDADE MUCURI-MU',
#        'FÁBRICA - UNIDADE MUCURI/INTERNO - MU', 'VITÓRIA-ES',
#        'VITÓRIA/ES', 'CARIACICA', 'IBIRAÇU', 'GUARAPARI', 'BAIXO GUANDÚ',
# ...

# %% [markdown]
# ## Transformações na coluna 'DESTINO'

# %%
df_combinado['DESTINO'].unique()
# Out:
# array(['FABRICA', 'TEIXEIRA DE FREITAS', 'POSTO DA MATA', 'ITABATA',
#        'POSTO DA MATA ', 'AEROPORTO', 'SÃO JOSÉ DE ALCOBAÇA',
#        'PEDRO CANÁRIO', 'CMC MUCURI X ITABATAN', 'FABRICA ',
#        'CONCEIÇÃO DA BARRA COCB', 'MUCURI', 'ITABATÃ CMC', 'TEIXEIRA',
#        'PEDRO CANARIO', 'VITORIA', 'SÃO MATEUS',
#        'TEIXEIRA/RAMAGRAF/MODULO3 PICADAO/POSTO DA MATA/TEIXEITA ATE AS 17:10',
#        'ITABATAN', 'GURIRI', 'CONCEIÇÃO DA BARRA', 'ITABATÃ',
#        'BRAÇO DO RIO', 'SAYONARA', 'VITÓRIA', 'ARACRUZ', 'SERRA',
#        'DIVISA', 'AÉRODROMO MAX FEFFER', 'CRISTAL DO NORTE', 'LINHARES',
#        'CACHOEIRO ITAPEMIRIM', 'CARAVELAS', 'MUCURI ', 'CRUZELANDIA',
#        'SITIO RAIZES', 'SÍTIO RAIZES', 'PORTO SEGURO', 'DIVISA BA/ES',
#        'FÁBRICA', 'COCB', 'DIVERSOS', 'CACHOEIRA ITAPEMIRIM',
#        'POSTO FLORESTA', 'NOVA VIÇOSA', 'SALOMÃO BRUNO FIGUEREDO',
#        'RANCHO ALEGRE', 'PEDRO CANÁRIO/ IDA  E VOLTA',
# ...

# %%
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("(","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace(")","")
# Out:
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\1938246535.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("(","")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\1938246535.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace(")","")

# %%
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.upper()
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.strip()

# %%
df_combinado['DESTINO'].unique()
# Out:
# array(['FABRICA', 'TEIXEIRA DE FREITAS', 'POSTO DA MATA', 'ITABATA',
#        'AEROPORTO', 'SÃO JOSÉ DE ALCOBAÇA', 'PEDRO CANÁRIO',
#        'CMC MUCURI X ITABATAN', 'CONCEIÇÃO DA BARRA COCB', 'MUCURI',
#        'ITABATÃ CMC', 'TEIXEIRA', 'PEDRO CANARIO', 'VITORIA',
#        'SÃO MATEUS',
#        'TEIXEIRA/RAMAGRAF/MODULO3 PICADAO/POSTO DA MATA/TEIXEITA ATE AS 17:10',
#        'ITABATAN', 'GURIRI', 'CONCEIÇÃO DA BARRA', 'ITABATÃ',
#        'BRAÇO DO RIO', 'SAYONARA', 'VITÓRIA', 'ARACRUZ', 'SERRA',
#        'DIVISA', 'AÉRODROMO MAX FEFFER', 'CRISTAL DO NORTE', 'LINHARES',
#        'CACHOEIRO ITAPEMIRIM', 'CARAVELAS', 'CRUZELANDIA', 'SITIO RAIZES',
#        'SÍTIO RAIZES', 'PORTO SEGURO', 'DIVISA BA/ES', 'FÁBRICA', 'COCB',
#        'DIVERSOS', 'CACHOEIRA ITAPEMIRIM', 'POSTO FLORESTA',
#        'NOVA VIÇOSA', 'SALOMÃO BRUNO FIGUEREDO', 'RANCHO ALEGRE',
#        'PEDRO CANÁRIO/ IDA  E VOLTA', 'CACHOEIRO ITAPEMIR.',
#        'CRUZELÂNDIA', 'GUIRIRI', 'ARACRUZ/ GURIRI', 'CARLOS CHAGAS',
# ...

# %%
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("   "," ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("  "," ")
df_combinado['ORIGEM'] = df_combinado['ORIGEM'].str.replace("    "," ")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. SEGURO","PORTO SEGURO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("MUCURIC","MUCURI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FÁBRICA MUCURIC","FÁBRICA MUCURI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. CANARIO","PEDRO CANÁRIO")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. CANARIO","PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("BRACO DO RIO","BRAÇO DO RIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("SÃO MATUES","SÃO MATEUS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("T. FREITAS","TEIXEIRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("TEIXEIRA DE FREITAS","TEIXEIRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("´PEDRO CANÁRIO","PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CONC. DA BARRA","CONCEIÇÃO DA BARRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CONCEIÇÃO BARRA","CONCEIÇÃO DA BARRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("VITORIA","VITÓRIA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("SAYNARA","SAYONARA")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CACHOEIRO DO ITAPEMIRIM","CACHOEIRO DE ITAPEMIRIM")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("´MUCURI","MUCURI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CRUZENLANDIA","CRUZELÂNDIA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATA","ITABATÃ")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FABRICA","FÁBRICA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("PED. CANÁRIO","PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("SAO MATEUS","SÃO MATEUS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CACHOEIRO ITAPEMIR.","CACHOEIRO DE ITAPEMIRIM")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CRUZELANDIA","CRUZELÂNDIA")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CON. DA BARRA","CONCEIÇÃO DA BARRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("TEIX. FREITAS","TEIXEIRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("TEIXEITA ","TEIXEIRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("TEIXEIRA","TEIXEIRA DE FREITAS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("PEDRO CANARIO","PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("POSTO MATA","POSTO DA MATA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("G. VALADARES","GOVERNADOR VALADARES")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("NOVA VENÉCIIA","NOVA VENÉCIA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. CANÁRIO","PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("S. MATEUS","SÃO MATEUS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. MATA","POSTO DA MATA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("CONCEIÇAO DA BARRA","CONCEIÇÃO DA BARRA")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("S.MATEUS","SÃO MATEUS")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("AMERICA","AMÉRICA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃN","ITABATÃ")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("N. VENECIA","NOVA VENÉCIA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃN","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃN","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FÁBRICA MUCURI","FÁBRICA MU")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("VITÓRIA AEROPORTO","VITÓRIA/AEROPORTO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FÁBRICA MU","FÁBRICA MUCURI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FABR. MUC","FÁBRICA MUCURI")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace(" - ES","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace(" - BA","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace(" - MG","")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("/ES","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("/INTERNO - MU","* MUCURI INTERNO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃI","ITABATÃ")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- PRADO","/PRADO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃI","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("/INTERNO - MU","* MUCURI INTERNO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃI","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("/INTERNO - MU","* MUCURI INTERNO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃI","ITABATÃ")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- SERRA","/SERRA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABATÃI","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-COLATINA","/COLATINA")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-ARACRUZ","/ARACRUZ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-MUCURI","/MUCURI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-ARACRUZ","/ARACRUZ")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ITABTAN","ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-ITABATÃ","/ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- LINHARES","/ LINHARES")


df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-PEDRO CANÁRIO","/PEDRO CANÁRIO")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-ES","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("ATE AS 17:10","")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- MUCURI","/ MUCURI")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- ITAMARAJÚ","/ ITAMARAJÚ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-SÃO MATEUS","/SÃO MATEUS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- ARACRUZ","/ ARACRUZ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-NOVA VIÇOSA","/NOVA VIÇOSA")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-TEIXEIRA DE FREITAS","/TEIXEIRA DE FREITAS")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-BRAÇO DO RIO","/BRAÇO DO RIO")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("X ITABATÃ","/ ITABATÃ")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("FÁBRICA  PRADO","FÁBRICA / PRADO")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("EUNAPOLIS","EUNÁPOLIS")

df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("-BA","")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("- GURIRI","/ GURIRI")
df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("/ IDA  E VOLTA","")
# Out:
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\3370867562.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. SEGURO","PORTO SEGURO")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\3370867562.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. CANARIO","PEDRO CANÁRIO")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\3370867562.py:10: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_combinado['DESTINO'] = df_combinado['DESTINO'].str.replace("P. CANARIO","PEDRO CANÁRIO")
# C:\Users\Markos Alves\AppData\Local\Temp\ipykernel_42824\3370867562.py:13: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
df_combinado['DESTINO'].unique()
# Out:
# array(['FÁBRICA', 'TEIXEIRA DE FREITAS', 'POSTO DA MATA', 'ITABATÃ',
#        'AEROPORTO', 'SÃO JOSÉ DE ALCOBAÇA', 'PEDRO CANÁRIO',
#        'CMC MUCURI / ITABATÃ', 'CONCEIÇÃO DA BARRA COCB', 'MUCURI',
#        'ITABATÃ CMC', 'VITÓRIA', 'SÃO MATEUS',
#        'TEIXEIRA DE FREITAS/RAMAGRAF/MODULO3 PICADAO/POSTO DA MATA/TEIXEIRA DE FREITAS',
#        'GURIRI', 'CONCEIÇÃO DA BARRA', 'BRAÇO DO RIO', 'SAYONARA',
#        'ARACRUZ', 'SERRA', 'DIVISA', 'AÉRODROMO MAX FEFFER',
#        'CRISTAL DO NORTE', 'LINHARES', 'CACHOEIRO DE ITAPEMIRIMM',
#        'CARAVELAS', 'CRUZELÂNDIA', 'SITIO RAIZES', 'SÍTIO RAIZES',
#        'PORTO SEGURO', 'DIVISA BA', 'COCB', 'DIVERSOS',
#        'CACHOEIRA ITAPEMIRIM', 'POSTO FLORESTA', 'NOVA VIÇOSA',
#        'SALOMÃO BRUNO FIGUEREDO', 'RANCHO ALEGRE',
#        'CACHOEIRO DE ITAPEMIRIM', 'GUIRIRI', 'ARACRUZ/ GURIRI',
#        'CARLOS CHAGAS', 'NOVA VENECIA', 'VIX-AEROPORTO', 'CURVELO-MG',
#        'NANUQUE', 'EUNÁPOLIS', 'CONCEIÇÃO  DA BARRA', 'VILA VELHA',
# ...

# %% [markdown]
# ## ALTERAÇÕES NA COLUNA 'PASSAGEIRO'

# %%
df_combinado['TIPO'] = df_combinado['TIPO'].astype(str)
df_combinado['TIPO'] = df_combinado['TIPO'].str.upper()
df_combinado['TIPO'] = df_combinado['TIPO'].str.strip()

# %%
df_combinado['TIPO'].unique()
# Out:
# array(['CHAMADA', 'NAN', 'TAXI', 'VAN'], dtype=object)

# %%
df_combinado['TIPO'] = df_combinado['TIPO'].str.replace('nan', "Não Informado")

# %%
df_combinado['TIPO'].unique()
# Out:
# array(['CHAMADA', 'NAN', 'TAXI', 'VAN'], dtype=object)

# %%
df_combinado.to_excel(r'C:\Users\Markos Alves\Downloads\terceirizadas horiginal\terceirizadas.xlsx'.replace("\\","/"))
